# %% [markdown]
# #Task 5 Custom Client Selection

# %%
! git clone https://github.com/Mattizza/FL-project.git

# %%
cd FL-project

# %%
! pip install wandb -q

# %%
# !git branch

# %% [markdown]
# ---

# %% [markdown]
# #### Task 5 - Biased Client Selection

# %%
# !python main.py --dataset idda \
                --wandb singleRun \
                --wb_project_name prova \
                --framework federated \
                --config bestHypSameDom.yaml \
                --transformConfig hue01.yaml \
                --bs 12 \
                --custom_client_selection true \
                --use_entropy true \
                --clients_per_round 8 \
                --num_epochs 1 \
                --num_rounds 50 \
                --r 10 \
                --beta 0 \
                --llambda 1 \
                --name_checkpoint_to_save prova_T5CS.pth.tar
