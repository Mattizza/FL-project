# %% [markdown]
# # Task 4

# %%
! git clone https://github.com/Mattizza/FL-project.git

# %%
cd FL-project

# %%
pip install wandb -q

# %%
# !git branch

# %% [markdown]
# ---

# %% [markdown]
# #### Task 4 - self-training with pseudo labels

# %%
# !python main.py --dataset idda \
                --framework federated \
                --clients_per_round 2 \
                --num_rounds 100 \
                --self_train true \
                --wandb singleRun \
                --wb_project_name prova \
                --source_trained_ckpt task3AdamGtaBestTransforms.pth.tar \
                --config bestHypSameDom.yaml \
                --transformConfig hue01.yaml \
                --num_epochs 1 \
                --r -1 \
                --bs 12 \
                --name_checkpoint_to_save prova.pth.tar
