# %% [markdown]
# # Task 3

# %%
! git clone https://github.com/Mattizza/FL-project.git

# %%
cd FL-project

# %%
! pip install wandb -q

# %%
# !git branch

# %% [markdown]
# You should load GTA5 images into `gta5/images` folder and labels in `gta5/labels` folder

# %% [markdown]
# ## Task3 - no FDA

# %%
# !python main.py --dataset gta5 \
                --wandb singleRun \
                --wb_project_name prova \
                --framework centralized \
                --name_checkpoint_to_save prova.pth.tar \
                --config task3AdamBest.yaml \
                --transformConfig bestTask3Transforms.yaml \
                --num_epochs 30 \
                --t 3 \
                --bs 8

# %% [markdown]
# ## Task3 - FDA

# %%
# !python main.py --dataset gta5 \
                --wandb singleRun \
                --wb_project_name prova \
                --framework centralized \
                --name_checkpoint_to_save prova.pth.tar \
                --config task3AdamBest.yaml \
                --transformConfig noTransforms.yaml \
                --fda true \
                --b 1 \
                --num_epochs 30 \
                --t 3 \
                --bs 8
