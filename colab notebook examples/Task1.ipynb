# %% [markdown]
# #Task 1

# %%
! git clone https://github.com/Mattizza/FL-project.git

# %%
cd FL-project

# %%
# !git branch

# %%
# !pip install wandb -q

# %% [markdown]
# ## Centralized Framework

# %%
# !python main.py --dataset idda \
                --framework centralized \
                --wandb singleRun \
                --wb_project_name randomTest \
                --config bestHypSameDom.yaml \
                --transformConfig sat06cont06.yaml \
                --num_epochs 50 \
                --bs 12

# %% [markdown]
# ## Hyperparameter Tuning

# %%
# !python main.py --dataset idda \
                --wandb hypTuning \
                --framework centralized \
                --transformConfig noTransforms.yaml \
                --wb_project_name randomTest \
                --num_epochs 10 \
                --bs 12 \
                --sweep_config hypTuningStep1_29_06.yaml

# %% [markdown]
# ## Transform Tuning

# %%
# !python main.py --dataset idda \
                --wandb transformTuning \
                --framework centralized \
                --config bestHypSameDom.yaml \
                --wb_project_name randomTest \
                --num_epochs 10 \
                --bs 12 \
                --sweep_config task1SweepColorJitter.yaml
