# %% [markdown]
# #Task 2

# %%
! git clone https://github.com/Mattizza/FL-project.git

# %%
cd FL-project

# %%
# !pip install wandb -q

# %%
# !git branch

# %% [markdown]
# ## Task 2 - Federated Framework

# %% [markdown]
# #### Task 2 + checkpoint saving

# %%
# !python main.py --dataset idda \
                --wandb singleRun \
                --wb_project_name randomTest \
                --framework federated \
                --clients_per_round 2 \
                --num_epochs 1 \
                --num_rounds 100 \
                --config bestHypSameDom.yaml \
                --transformConfig hue01.yaml \
                --r 5 \
                --bs 12 \
                --name_checkpoint_to_save prova.pth.tar

# %% [markdown]
# #### Task 2 + checkpoint loading and saving

# %%
# !python main.py --dataset idda \
                --wandb singleRun \
                --wb_project_name randomTest \
                --framework federated \
                --clients_per_round 2 \
                --num_epochs 1 \
                --num_rounds 100 \
                --config bestHypSameDom.yaml \
                --transformConfig hue01.yaml \
                --bs 12 \
                --r 5 \
                --checkpoint_to_load prova.pth.tar \
                --name_checkpoint_to_save prova.pth.tar
