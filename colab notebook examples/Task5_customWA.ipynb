# %% [markdown]
# # Task 5 Custom Weight Aggregation

# %%
! git clone https://github.com/Mattizza/FL-project.git

# %%
cd FL-project

# %%
pip install wandb -q

# %%
# !git branch

# %% [markdown]
# ---

# %% [markdown]
# #### Task 5 - Our Weight Aggregation

# %%
# !python mainWA.py --dataset idda \
                      --framework federated \
                      --wandb singleRun \
                      --wb_project_name prova \
                      --config bestHypSameDom.yaml \
                      --transformConfig hue01.yaml \
                      --bs 12 \
                      --use_entropy true \
                      --b 1 \
                      --alpha_weight_agg 0 \
                      --custom_weight_agg true \
                      --clients_per_round 4 \
                      --num_epochs 2 \
                      --num_rounds 50 \
                      --r -1 \
                      --beta_weight_agg 0.25 \
                      --llambda_weight_agg 1 \
                      --name_checkpoint_to_save prova.pth.tar
